# %% [markdown]
# # Time Cell Minimal Loop (Train → Evaluate → Plot)
# This notebook is **self-contained** (no `torchvision` dependency) and is designed to run a minimal closed-loop pipeline:
# 1) Load variable-length trajectory folders (pkl + images)
# 2) Train a Visual-Temporal LSTM model
# 3) Evaluate (MSE/R²) and plot predicted vs GT trajectory
#
# **You only need to set `DATA_ROOT_DIR` to your dataset path.**

# %%
# [Cell 1] Imports & Setup (保留并更新)
# %load_ext autoreload
# %autoreload 2

import torch
from torch.utils.data import DataLoader

# ✅ 新增：导入你刚才新建/修改的模块
from dataset import VariableLengthTrajectoryDataset, collate_variable_length
from model.visualNet import VisualTemporalNet_Optimized  # 导入新模型
from model.metrics import NMI_Evaluator

# ✅ 数据加载逻辑 (必须保留，因为 run_experiment 需要传入 dataset 实例)
DATA_ROOT_DIR = "/media/zhen/Data/Datasets/nomad_data/go_stanford" 
# 或者是你原本的路径变量
ds = VariableLengthTrajectoryDataset(DATA_ROOT_DIR, min_len=10)
print(f"Dataset loaded: {len(ds)} trajectories")
# Out:
# Using device: cuda

# %%
# === 1) Config (EDIT THIS) ===
DATA_ROOT_DIR = "/media/zhen/Data/Datasets/nomad_data/go_stanford"  # <-- CHANGE ME
SAVE_DIR = "./eval_results_minimal"
os.makedirs(SAVE_DIR, exist_ok=True)

BATCH_SIZE = 8
EPOCHS = 50           # start small for sanity; increase later (e.g., 50-200)
LR = 1e-4
HIDDEN_DIM = 128
VISUAL_DIM = 256

USE_YAW = True
MIN_LEN = 3
IMG_SIZE = (64, 64)

CKPT_PATH = os.path.join(SAVE_DIR, "best_timecell_model.pth")

# %%
def run_experiment(exp_name, dataset, ablation_config=None, epochs=20, device='cuda'):
    """
    自动化实验流程：
    1. 初始化模型 (支持结构消融)
    2. 训练 loop (带 RMSE 监控)
    3. 评估 loop (生成 NMI 风格图表)
    """
    print(f"\n{'='*10} Start Experiment: {exp_name} {'='*10}")
    save_dir = f"./eval_results/{exp_name}"
    os.makedirs(save_dir, exist_ok=True)
    
    # 1. Build Model
    model = VisualTemporalNet_Optimized(
        feature_dim=3, # 假设 dataset 输出是 x, y, yaw
        output_dim=2,  # 预测 x, y
        ablation_config=ablation_config
    ).to(device)
    
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.MSELoss() # 或者 SmoothL1Loss
    
    # 2. Training Loop
    loader = DataLoader(dataset, batch_size=4, shuffle=True, collate_fn=collate_variable_length)
    
    model.train()
    for epoch in range(epochs):
        epoch_loss = 0
        all_preds, all_targets = [], []
        
        for feats, imgs, targets, mask in loader:
            feats, imgs, targets, mask = feats.to(device), imgs.to(device), targets.to(device), mask.to(device)
            
            optimizer.zero_grad()
            preds, _ = model(feats, imgs, mask)
            
            # Masking Loss (只计算有效时间步的 loss)
            loss = (criterion(preds, targets[:,:,:2]) * mask.unsqueeze(-1)).sum() / mask.sum()
            
            loss.backward()
            optimizer.step()
            
            epoch_loss += loss.item()
            
            # Collect for metrics (Optional: only last epoch)
            if epoch == epochs - 1:
                # 只取有效部分用于计算指标
                for b in range(preds.shape[0]):
                    L = int(mask[b].sum().item())
                    all_preds.append(preds[b, :L, :].detach().cpu().numpy())
                    all_targets.append(targets[b, :L, :2].detach().cpu().numpy())
        
        if (epoch+1) % 5 == 0:
            print(f"Epoch {epoch+1}/{epochs} | Loss: {epoch_loss/len(loader):.4f}")

    # 3. Final Metrics (Training Set for sanity check)
    if all_preds:
        flat_preds = np.concatenate(all_preds, axis=0)
        flat_targets = np.concatenate(all_targets, axis=0)
        metrics = NMI_Evaluator.calculate_metrics(flat_targets, flat_preds)
        NMI_Evaluator.print_summary(metrics, prefix="Train Final")
    
    # 4. Standard Evaluation Pipeline (Main_cell style)
    print("\n--- Running Standard Evaluation ---")
    
    # (A) Time Cell Analysis (Heatmap, TSI, PCA)
    # 使用你优化后的 plotcell
    cell_results = plotcell.analyze_time_cells(model, loader, device, save_dir=save_dir)
    
    # (B) Ablation Evaluation (Post-hoc inference ablation)
    # 使用你优化后的 evalcell
    if cell_results:
        evalcell.evaluate_time_scales_and_extensions(model, loader, cell_results, device, save_dir=save_dir)
        
    # (C) Trajectory Correlation (Feature encoding check)
    # 使用你优化后的 evaltraj
    if cell_results:
        evaltraj.evaluate_timecell_trajectory_correlation(model, loader, cell_results, device, save_dir=save_dir)
        
    # (D) Final Trajectory Visualization
    evaltraj.evaluate_and_visualize(model, loader, device, save_dir=save_dir, save_prefix=exp_name, plot=True)
    
    return metrics, cell_results

# %%
# === 2) Dataset (variable-length trajectory folders: traj_data.pkl + images) ===

def sort_key(path: str) -> int:
    nums = re.findall(r"\d+", os.path.basename(path))
    return int(nums[-1]) if nums else 0

def pil_to_tensor(img: Image.Image) -> torch.Tensor:
    """Convert PIL RGB image to torch float tensor [3,H,W] in [0,1] without torchvision."""
    arr = np.asarray(img, dtype=np.float32) / 255.0  # [H,W,3]
    if arr.ndim == 2:
        arr = np.repeat(arr[..., None], 3, axis=2)
    arr = np.transpose(arr, (2, 0, 1))              # [3,H,W]
    return torch.from_numpy(arr)

class VariableLengthTrajectoryDataset(Dataset):
    """
    Each trajectory is a folder containing:
      - traj_data.pkl with keys: 'position' (Tx2 or Tx3), 'yaw' (T,)
      - images: *.jpg or *.png directly under the folder
    Target: last position (pos[-1])
    Features per step: [pos, yaw] (if USE_YAW) else [pos]
    """
    def __init__(self, root_dir: str, use_yaw: bool=True, min_len: int=3, img_size=(64,64)):
        if not os.path.exists(root_dir):
            raise FileNotFoundError(f"Dataset root directory not found: {root_dir}")
        self.root_dir = root_dir
        self.use_yaw = use_yaw
        self.min_len = min_len
        self.img_size = img_size

        self.trajectories = sorted([
            os.path.join(root_dir, d)
            for d in os.listdir(root_dir)
            if os.path.isdir(os.path.join(root_dir, d))
        ])
        if len(self.trajectories) == 0:
            raise ValueError(f"No trajectory folders found under: {root_dir}")
        print(f"✅ Found {len(self.trajectories)} trajectories in {root_dir}")

        # infer dims from first valid sample
        self.target_dim = None
        self.input_feature_dim = None
        for tp in self.trajectories[:10]:
            pkl_path = os.path.join(tp, "traj_data.pkl")
            if not os.path.exists(pkl_path):
                continue
            with open(pkl_path, "rb") as f:
                data = pickle.load(f)
            pos = np.asarray(data.get("position", []), dtype=np.float32)
            yaw = np.asarray(data.get("yaw", []), dtype=np.float32)
            if pos.ndim != 2 or len(pos) < self.min_len:
                continue
            self.target_dim = pos.shape[1]
            self.input_feature_dim = self.target_dim + (1 if (self.use_yaw and yaw.size > 0) else 0)
            break
        if self.target_dim is None:
            raise RuntimeError("Failed to infer target_dim/input_feature_dim. Check your pkl files.")
        print(f"Detected target_dim (position) = {self.target_dim}")
        print(f"Detected input_feature_dim (pos + yaw={self.use_yaw}) = {self.input_feature_dim}")

    def __len__(self):
        return len(self.trajectories)

    def _load_pkl(self, traj_path):
        pkl_path = os.path.join(traj_path, "traj_data.pkl")
        if not os.path.exists(pkl_path):
            return None
        with open(pkl_path, "rb") as f:
            data = pickle.load(f)
        pos = np.asarray(data["position"], dtype=np.float32)
        yaw = np.asarray(data.get("yaw", []), dtype=np.float32)
        return pos, yaw

    def _load_images(self, traj_path):
        img_files = sorted(glob(os.path.join(traj_path, "*.jpg")), key=sort_key)
        if not img_files:
            img_files = sorted(glob(os.path.join(traj_path, "*.png")), key=sort_key)
        imgs = []
        for fp in img_files:
            img = Image.open(fp).convert("RGB").resize(self.img_size)
            imgs.append(pil_to_tensor(img))
        if len(imgs) == 0:
            return None
        return torch.stack(imgs, dim=0)  # [T,3,H,W]

    def __getitem__(self, idx):
        traj_path = self.trajectories[idx]
        loaded = self._load_pkl(traj_path)
        if loaded is None:
            return None
        pos, yaw = loaded
        imgs = self._load_images(traj_path)
        if imgs is None:
            return None

        T = min(len(pos), imgs.shape[0])
        if T < self.min_len:
            return None

        pos = pos[:T]
        imgs = imgs[:T]
        if self.use_yaw and yaw.size > 0:
            yaw = yaw[:T].reshape(T, 1).astype(np.float32)
            feats = np.concatenate([pos, yaw], axis=1)  # [T, Dpos+1]
        else:
            feats = pos  # [T, Dpos]

        feats = torch.from_numpy(feats).float()
        target = torch.from_numpy(pos[-1]).float()     # [Dpos]
        return feats, imgs, target

def collate_variable_length(batch):
    batch = [b for b in batch if b is not None]
    if len(batch) == 0:
        return None, None, None, None
    feats, imgs, targets = zip(*batch)
    lengths = [f.shape[0] for f in feats]
    max_len = max(lengths)

    B = len(batch)
    feat_dim = feats[0].shape[1]
    C, H, W = imgs[0].shape[1], imgs[0].shape[2], imgs[0].shape[3]

    feats_pad = torch.zeros(B, max_len, feat_dim, dtype=torch.float32)
    imgs_pad  = torch.zeros(B, max_len, C, H, W, dtype=torch.float32)
    mask      = torch.zeros(B, max_len, dtype=torch.bool)

    for i, (f, im) in enumerate(zip(feats, imgs)):
        L = f.shape[0]
        feats_pad[i, :L] = f
        imgs_pad[i, :L] = im
        mask[i, :L] = True

    targets = torch.stack(targets, dim=0)
    return feats_pad, imgs_pad, targets, mask

# build loader
dataset = VariableLengthTrajectoryDataset(DATA_ROOT_DIR, use_yaw=USE_YAW, min_len=MIN_LEN, img_size=IMG_SIZE)
loader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True, collate_fn=collate_variable_length)

# sanity: peek one batch
batch = next(iter(loader))
feats, imgs, targets, mask = batch
print("feats:", feats.shape, "imgs:", imgs.shape, "targets:", targets.shape, "mask:", mask.shape, "mask_valid:", mask.sum().item())
# Out:
# ✅ Found 3696 trajectories in /media/zhen/Data/Datasets/nomad_data/go_stanford
# Detected target_dim (position) = 2
# Detected input_feature_dim (pos + yaw=True) = 3
# feats: torch.Size([5, 47, 3]) imgs: torch.Size([5, 47, 3, 64, 64]) targets: torch.Size([5, 2]) mask: torch.Size([5, 47]) mask_valid: 149
# /tmp/ipykernel_2210756/3220069749.py:50: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   yaw = np.asarray(data.get("yaw", []), dtype=np.float32)
# /tmp/ipykernel_2210756/3220069749.py:71: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   yaw = np.asarray(data.get("yaw", []), dtype=np.float32)

# %%
# === 4) Train (minimal) ===

def train_minimal(model, loader, device, epochs=20, lr=1e-4, ckpt_path=CKPT_PATH):
    model.to(device)
    loss_fn = nn.SmoothL1Loss()
    optim = torch.optim.Adam(model.parameters(), lr=lr)
    best = float("inf")

    for ep in range(1, epochs+1):
        model.train()
        total = 0.0
        n = 0
        for batch in loader:
            feats, imgs, targets, mask = batch
            if feats is None:
                continue
            feats, imgs, targets, mask = feats.to(device), imgs.to(device), targets.to(device), mask.to(device)

            optim.zero_grad(set_to_none=True)
            pred, _ = model(feats, imgs, mask)

            loss = loss_fn(pred, targets)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 5.0)
            optim.step()

            total += loss.item()
            n += 1

        avg = total / max(n, 1)
        print(f"Epoch {ep}/{epochs} | loss={avg:.6f}")

        if avg < best:
            best = avg
            torch.save(model.state_dict(), ckpt_path)
            print(f"✅ New best saved: {ckpt_path} (loss={best:.6f})")

    return ckpt_path

ckpt = train_minimal(model, loader, device, epochs=EPOCHS, lr=LR, ckpt_path=CKPT_PATH)
# Out:
# /tmp/ipykernel_2210756/3220069749.py:71: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   yaw = np.asarray(data.get("yaw", []), dtype=np.float32)
# Epoch 1/50 | loss=12.235080
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=12.235080)
# Epoch 2/50 | loss=10.682957
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=10.682957)
# Epoch 3/50 | loss=9.316510
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=9.316510)
# Epoch 4/50 | loss=8.138207
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=8.138207)
# Epoch 5/50 | loss=7.133211
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=7.133211)
# Epoch 6/50 | loss=6.223023
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=6.223023)
# Epoch 7/50 | loss=5.511109
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=5.511109)
# Epoch 8/50 | loss=4.901803
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=4.901803)
# Epoch 9/50 | loss=4.329851
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=4.329851)
# Epoch 10/50 | loss=3.898232
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=3.898232)
# Epoch 11/50 | loss=3.426803
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=3.426803)
# Epoch 12/50 | loss=3.060135
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=3.060135)
# Epoch 13/50 | loss=2.787875
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=2.787875)
# Epoch 14/50 | loss=2.497867
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=2.497867)
# Epoch 15/50 | loss=2.202488
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=2.202488)
# Epoch 16/50 | loss=2.029865
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=2.029865)
# Epoch 17/50 | loss=1.818178
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=1.818178)
# Epoch 18/50 | loss=1.663075
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=1.663075)
# Epoch 19/50 | loss=1.520713
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=1.520713)
# Epoch 20/50 | loss=1.386845
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=1.386845)
# Epoch 21/50 | loss=1.281979
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=1.281979)
# Epoch 22/50 | loss=1.159762
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=1.159762)
# Epoch 23/50 | loss=1.036739
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=1.036739)
# Epoch 24/50 | loss=0.971786
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=0.971786)
# Epoch 25/50 | loss=0.901944
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=0.901944)
# Epoch 26/50 | loss=0.814483
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=0.814483)
# Epoch 27/50 | loss=0.744258
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=0.744258)
# Epoch 28/50 | loss=0.741987
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=0.741987)
# Epoch 29/50 | loss=0.667290
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=0.667290)
# Epoch 30/50 | loss=0.653587
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=0.653587)
# Epoch 31/50 | loss=0.599146
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=0.599146)
# Epoch 32/50 | loss=0.565851
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=0.565851)
# Epoch 33/50 | loss=0.529025
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=0.529025)
# Epoch 34/50 | loss=0.499558
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=0.499558)
# Epoch 35/50 | loss=0.488982
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=0.488982)
# Epoch 36/50 | loss=0.452506
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=0.452506)
# Epoch 37/50 | loss=0.455486
# Epoch 38/50 | loss=0.429650
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=0.429650)
# Epoch 39/50 | loss=0.394575
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=0.394575)
# Epoch 40/50 | loss=0.415142
# Epoch 41/50 | loss=0.382291
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=0.382291)
# Epoch 42/50 | loss=0.368700
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=0.368700)
# Epoch 43/50 | loss=0.361153
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=0.361153)
# Epoch 44/50 | loss=0.344021
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=0.344021)
# Epoch 45/50 | loss=0.341217
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=0.341217)
# Epoch 46/50 | loss=0.346205
# Epoch 47/50 | loss=0.312356
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=0.312356)
# Epoch 48/50 | loss=0.310292
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=0.310292)
# Epoch 49/50 | loss=0.299839
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=0.299839)
# Epoch 50/50 | loss=0.286830
# ✅ New best saved: ./eval_results_minimal/best_timecell_model.pth (loss=0.286830)

# %%
# === 5) Evaluate + Plot (minimal loop output) ===

@torch.no_grad()
def evaluate_and_plot(model, loader, device, ckpt_path, save_dir=SAVE_DIR, prefix="timecell"):
    os.makedirs(save_dir, exist_ok=True)
    model.load_state_dict(torch.load(ckpt_path, map_location=device))
    model.to(device)
    model.eval()

    preds_all, targets_all = [], []
    for batch in loader:
        feats, imgs, targets, mask = batch
        if feats is None:
            continue
        feats, imgs, targets, mask = feats.to(device), imgs.to(device), targets.to(device), mask.to(device)
        pred, _ = model(feats, imgs, mask)
        preds_all.append(pred.detach().cpu().numpy())
        targets_all.append(targets.detach().cpu().numpy())

    preds_all = np.concatenate(preds_all, axis=0)
    targets_all = np.concatenate(targets_all, axis=0)

    mse = mean_squared_error(targets_all, preds_all)
    r2 = r2_score(targets_all, preds_all)
    print(f"Eval | MSE={mse:.6f} | R2={r2:.4f}")

    np.save(os.path.join(save_dir, f"{prefix}_preds.npy"), preds_all)
    np.save(os.path.join(save_dir, f"{prefix}_targets.npy"), targets_all)

    # Trajectory plot (assumes first 2 dims are x,y)
    if preds_all.shape[1] >= 2 and targets_all.shape[1] >= 2:
        plt.figure(figsize=(6,6))
        plt.plot(targets_all[:,0], targets_all[:,1], '-', linewidth=2, label="Ground Truth")
        plt.plot(preds_all[:,0], preds_all[:,1], '--', linewidth=2, label="Prediction")
        plt.title(f"Trajectory (MSE={mse:.4f}, R2={r2:.3f})")
        plt.xlabel("X"); plt.ylabel("Y")
        plt.grid(True); plt.legend()
        out_path = os.path.join(save_dir, f"{prefix}_traj.png")
        plt.tight_layout()
        plt.savefig(out_path, dpi=200)
        plt.show()
        print("Saved plot:", out_path)
    else:
        print("Skip trajectory plot: target_dim < 2")

    # metrics csv
    import pandas as pd
    pd.DataFrame([{"MSE": mse, "R2": r2, "n": len(preds_all)}]).to_csv(
        os.path.join(save_dir, f"{prefix}_metrics.csv"), index=False
    )
    return preds_all, targets_all, {"MSE": mse, "R2": r2}

preds, targets, metrics = evaluate_and_plot(model, loader, device, ckpt, save_dir=SAVE_DIR, prefix="timecell_minimal")
# Out:
# /tmp/ipykernel_2210756/3220069749.py:71: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   yaw = np.asarray(data.get("yaw", []), dtype=np.float32)
# Eval | MSE=9.855585 | R2=0.9743
# Saved plot: ./eval_results_minimal/timecell_minimal_traj.png

# %% [markdown]
# # Step 1 (continued): Time-cell mechanism figures
# Run time-cell analyses **after** training. This will generate heatmaps, peak-time histograms, TSI, PCA projections, and more.
#
# We will reuse your existing modules:
# - `plotcell.py`: `analyze_time_cells`
# - `evalcell.py`: `evaluate_time_scales_and_extensions`
# - `evaltraj.py`: `evaluate_timecell_trajectory_correlation`
#
# These files are expected to be available under `/mnt/data/` (uploaded in this chat).

# %%
# === 6) Load your existing analysis modules (plotcell / evalcell / evaltraj) ===
import importlib.util, sys

def import_from_path(mod_name, path):
    spec = importlib.util.spec_from_file_location(mod_name, path)
    mod = importlib.util.module_from_spec(spec)
    sys.modules[mod_name] = mod
    spec.loader.exec_module(mod)
    return mod


EVALCELL_PATH = "/media/zhen/Data/cogMap/biw/scale_ablation/model/evalcell.py"
EVALTRAJ_PATH = "/media/zhen/Data/cogMap/biw/scale_ablation/model/evaltraj.py"
PLOTCELL_PATH = "/media/zhen/Data/cogMap/biw/scale_ablation/model/plotcell.py"

plotcell = import_from_path("plotcell", PLOTCELL_PATH)
evalcell = import_from_path("evalcell", EVALCELL_PATH)
evaltraj = import_from_path("evaltraj", EVALTRAJ_PATH)

print("Loaded:", plotcell, evalcell, evaltraj)
# Out:
# Loaded: <module 'plotcell' from '/media/zhen/Data/cogMap/biw/scale_ablation/model/plotcell.py'> <module 'evalcell' from '/media/zhen/Data/cogMap/biw/scale_ablation/model/evalcell.py'> <module 'evaltraj' from '/media/zhen/Data/cogMap/biw/scale_ablation/model/evaltraj.py'>

# %%
# [Cell 4] Execute Comparisons

# 1. 完整模型 (Full Model)
# 预期：RMSE 最低，TSI 分布最广
metrics_full, _ = run_experiment(
    "Exp_Full_Fusion", 
    dataset, 
    ablation_config={'use_visual': True, 'use_kinematics': True}
)

# 2. 仅视觉 (Visual Only) - 模拟你之前的模型状态
# 预期：RMSE 较高 (因为丢失了动力学输入)，Time cells 更多响应视觉变化而非空间位置
metrics_vis, _ = run_experiment(
    "Exp_Visual_Only", 
    dataset, 
    ablation_config={'use_visual': True, 'use_kinematics': False}
)

# 3. 仅动力学 (Kinematics Only) - 类似里程计
# 预期：短时精度高，长时漂移，Time cells 表现为 Path Integration Cells
metrics_kin, _ = run_experiment(
    "Exp_Kinematics_Only", 
    dataset, 
    ablation_config={'use_visual': False, 'use_kinematics': True}
)

# --- 打印对比表 ---
print("\n========== Ablation Summary ==========")
print(f"Full Model RMSE: {metrics_full['RMSE']:.4f}")
print(f"Visual Only RMSE: {metrics_vis['RMSE']:.4f}")
print(f"Kinematics Only RMSE: {metrics_kin['RMSE']:.4f}")

# %%
# === 6.1) Generate time-cell mechanism plots (heatmap / peak / TSI / PCA) ===
# NOTE: Uses the trained model weights
model.load_state_dict(torch.load(CKPT_PATH, map_location=device))
model.to(device).eval()

plotcell.analyze_time_cells(
    model=model,
    loader=loader,
    device=device,
    n_cells_to_plot=64,   # 原 max_cells_to_plot → n_cells_to_plot
    save_dir=SAVE_DIR
)

print("✅ Time-cell figures saved under:", SAVE_DIR)

res = plotcell.analyze_time_cells(
    model=model,
    loader=loader,
    device=device,
    n_cells_to_plot=64,
    save_dir=SAVE_DIR
)
print("pca3_explained_variance:", res.get("pca3_explained_variance"))
# Out:
# /tmp/ipykernel_2210756/3220069749.py:71: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   yaw = np.asarray(data.get("yaw", []), dtype=np.float32)
# Hidden states padded to (2892, 849, 128)
# Preparing data for PCA...
# ✅ Time-cell figures saved under: ./eval_results_minimal
# /tmp/ipykernel_2210756/3220069749.py:71: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   yaw = np.asarray(data.get("yaw", []), dtype=np.float32)
# Hidden states padded to (2892, 849, 128)
# Preparing data for PCA...
# pca3_explained_variance: [0.898920476436615, 0.08511044830083847, 0.008021404035389423]

# %% [markdown]
# # Step 2: Core ablation #1 — Single-scale vs Multi-scale (Main table)
# We implement a **multi-scale** variant by running multiple temporal resolutions (strides) through separate LSTMs and fusing their last hidden states.
#
# We also provide a **single-scale** baseline (stride=1 only).
#
# In this notebook, we map **temporal scale α ∈ [0,1]** to a stride list.
# - α close to 0 → short timescale (fine resolution)
# - α close to 1 → long timescale (coarse resolution)
#
# For the paper, you can report α as normalized timescale weights (0–1).

# %%
# === 7) Multi-scale model (temporal pyramid via multi-stride LSTMs) ===
# This keeps the same CNN encoder; only the temporal module changes.

class MultiScaleVisualTemporalNet(nn.Module):
    def __init__(self, feature_dim: int, hidden_dim: int, visual_dim: int, output_dim: int,
                 strides=(1,2,4)):
        super().__init__()
        self.feature_dim = feature_dim
        self.hidden_dim = hidden_dim
        self.visual_dim = visual_dim
        self.output_dim = output_dim
        self.strides = tuple(strides)

        # Same CNN encoder as before
        self.cnn = nn.Sequential(
            nn.Conv2d(3, 32, 3, stride=2, padding=1), nn.ReLU(),
            nn.Conv2d(32, 64, 3, stride=2, padding=1), nn.ReLU(),
            nn.Conv2d(64, 128, 3, stride=2, padding=1), nn.ReLU(),
            nn.Flatten(),
            nn.Linear(128 * 8 * 8, visual_dim), nn.ReLU()
        )

        # One LSTM per temporal scale (stride)
        self.lstms = nn.ModuleList([
            nn.LSTM(input_size=feature_dim + visual_dim,
                    hidden_size=hidden_dim,
                    num_layers=1,
                    batch_first=True)
            for _ in self.strides
        ])

        # Fusion (learnable) across scales
        self.fuse = nn.Linear(len(self.strides) * hidden_dim, hidden_dim)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def _downsample(self, x, mask, stride: int):
        # x: [B,T,D], mask: [B,T]
        x_ds = x[:, ::stride, :]
        mask_ds = mask[:, ::stride]
        return x_ds, mask_ds

    def forward(self, feats, imgs, mask):
        B, T, _, H, W = imgs.shape
        v = self.cnn(imgs.view(B*T, 3, H, W)).view(B, T, self.visual_dim)
        x = torch.cat([feats, v], dim=-1)  # [B,T,D]

        last_states = []
        base_lstm_out = None

        for i, stride in enumerate(self.strides):
            x_s, m_s = self._downsample(x, mask, stride)
            lengths = m_s.sum(dim=1).long().cpu()
            packed = nn.utils.rnn.pack_padded_sequence(x_s, lengths, batch_first=True, enforce_sorted=False)
            packed_out, _ = self.lstms[i](packed)
            out_s, _ = nn.utils.rnn.pad_packed_sequence(packed_out, batch_first=True, total_length=x_s.shape[1])
            idx = (lengths - 1).clamp(min=0).to(out_s.device)
            last = out_s[torch.arange(B, device=out_s.device), idx]  # [B,H]
            last_states.append(last)

            # keep stride=1 outputs as "time-cell population" for analyses
            if stride == 1:
                # upsample back to T for compatibility (pad with zeros beyond valid length)
                base_lstm_out = torch.zeros(B, T, self.hidden_dim, device=out_s.device, dtype=out_s.dtype)
                base_lstm_out[:, :out_s.shape[1], :] = out_s

        fused = self.fuse(torch.cat(last_states, dim=-1))  # [B,H]
        pred = self.fc(fused)                              # [B,output_dim]
        return pred, base_lstm_out

def make_strides_from_alpha(alpha_list):
    """Map temporal scales α∈[0,1] to integer strides.
    A simple mapping: stride = 2**round(2*alpha) -> {1,2,4}.
    You can change this mapping later for your paper ablation.
    """
    strides = []
    for a in alpha_list:
        a = float(np.clip(a, 0.0, 1.0))
        s = int(2 ** int(round(2 * a)))  # 0->1, 0.5->2, 1->4
        strides.append(s)
    # unique & sorted
    return tuple(sorted(set(strides)))

print("✅ Multi-scale class ready.")
# Out:
# ✅ Multi-scale class ready.

# %%
# === 7.1) Train & evaluate helper for ablations (reuses earlier train/eval) ===
import pandas as pd

def train_and_eval(model, loader, device, epochs, lr, ckpt_path, prefix, save_dir):
    # train
    _ = train_minimal(model, loader, device, epochs=epochs, lr=lr, ckpt_path=ckpt_path)
    # eval
    preds, targets, metrics = evaluate_and_plot(model, loader, device, ckpt_path, save_dir=save_dir, prefix=prefix)
    return metrics

def run_multiscale_ablation(alpha_scales, exp_tag):
    strides = make_strides_from_alpha(alpha_scales)
    print(f"[{exp_tag}] alpha_scales={alpha_scales} -> strides={strides}")

    m = MultiScaleVisualTemporalNet(
        feature_dim=dataset.input_feature_dim,
        hidden_dim=HIDDEN_DIM,
        visual_dim=VISUAL_DIM,
        output_dim=dataset.target_dim,
        strides=strides
    ).to(device)

    ckpt_path = os.path.join(SAVE_DIR, f"{exp_tag}_best.pth")
    metrics = train_and_eval(
        m, loader, device,
        epochs=EPOCHS, lr=LR,
        ckpt_path=ckpt_path,
        prefix=exp_tag,
        save_dir=SAVE_DIR
    )
    metrics.update({"exp": exp_tag, "alpha_scales": str(alpha_scales), "strides": str(strides)})
    return metrics

# === Step 2 runs ===
# Single-scale baseline: alpha=[0.0] -> stride {1}
# Multi-scale (example): alpha=[0.0, 0.5, 1.0] -> strides {1,2,4}
results = []
results.append(run_multiscale_ablation([0.0], exp_tag="single_scale"))

# Multi-scale: (you can change alpha list later; both alpha and lambda should be in [0,1])
results.append(run_multiscale_ablation([0.0, 0.5, 1.0], exp_tag="multi_scale"))

df = pd.DataFrame(results)
out_csv = os.path.join(SAVE_DIR, "ablation_step2_single_vs_multi.csv")
df.to_csv(out_csv, index=False)
print("✅ Step 2 summary saved:", out_csv)
df
# Out:
# [single_scale] alpha_scales=[0.0] -> strides=(1,)
# /tmp/ipykernel_2210756/3220069749.py:71: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   yaw = np.asarray(data.get("yaw", []), dtype=np.float32)
# Epoch 1/50 | loss=10.686704
# ✅ New best saved: ./eval_results_minimal/single_scale_best.pth (loss=10.686704)
# Epoch 2/50 | loss=5.844398
# ✅ New best saved: ./eval_results_minimal/single_scale_best.pth (loss=5.844398)
# Epoch 3/50 | loss=2.963890
# ✅ New best saved: ./eval_results_minimal/single_scale_best.pth (loss=2.963890)
# Epoch 4/50 | loss=1.613554
# ✅ New best saved: ./eval_results_minimal/single_scale_best.pth (loss=1.613554)
# Epoch 5/50 | loss=1.119834
# ✅ New best saved: ./eval_results_minimal/single_scale_best.pth (loss=1.119834)
# Epoch 6/50 | loss=0.824609
# ✅ New best saved: ./eval_results_minimal/single_scale_best.pth (loss=0.824609)
# Epoch 7/50 | loss=0.623545
# ✅ New best saved: ./eval_results_minimal/single_scale_best.pth (loss=0.623545)
# Epoch 8/50 | loss=0.525250
# ✅ New best saved: ./eval_results_minimal/single_scale_best.pth (loss=0.525250)
# Epoch 9/50 | loss=0.459601
# ✅ New best saved: ./eval_results_minimal/single_scale_best.pth (loss=0.459601)
# Epoch 10/50 | loss=0.377341
# ✅ New best saved: ./eval_results_minimal/single_scale_best.pth (loss=0.377341)
# Epoch 11/50 | loss=0.331585
# ✅ New best saved: ./eval_results_minimal/single_scale_best.pth (loss=0.331585)
# Epoch 12/50 | loss=0.259361
# ✅ New best saved: ./eval_results_minimal/single_scale_best.pth (loss=0.259361)
# Epoch 13/50 | loss=0.254608
# ✅ New best saved: ./eval_results_minimal/single_scale_best.pth (loss=0.254608)
# Epoch 14/50 | loss=0.226124
# ✅ New best saved: ./eval_results_minimal/single_scale_best.pth (loss=0.226124)
# Epoch 15/50 | loss=0.209707
# ✅ New best saved: ./eval_results_minimal/single_scale_best.pth (loss=0.209707)
# Epoch 16/50 | loss=0.199122
# ✅ New best saved: ./eval_results_minimal/single_scale_best.pth (loss=0.199122)
# Epoch 17/50 | loss=0.191932
# ✅ New best saved: ./eval_results_minimal/single_scale_best.pth (loss=0.191932)
# Epoch 18/50 | loss=0.174847
# ✅ New best saved: ./eval_results_minimal/single_scale_best.pth (loss=0.174847)
# Epoch 19/50 | loss=0.155791
# ✅ New best saved: ./eval_results_minimal/single_scale_best.pth (loss=0.155791)
# Epoch 20/50 | loss=0.154209
# ✅ New best saved: ./eval_results_minimal/single_scale_best.pth (loss=0.154209)
# Epoch 21/50 | loss=0.144189
# ✅ New best saved: ./eval_results_minimal/single_scale_best.pth (loss=0.144189)
# Epoch 22/50 | loss=0.144953
# Epoch 23/50 | loss=0.136357
# ✅ New best saved: ./eval_results_minimal/single_scale_best.pth (loss=0.136357)
# Epoch 24/50 | loss=0.126342
# ✅ New best saved: ./eval_results_minimal/single_scale_best.pth (loss=0.126342)
# Epoch 25/50 | loss=0.119261
# ✅ New best saved: ./eval_results_minimal/single_scale_best.pth (loss=0.119261)
# Epoch 26/50 | loss=0.103394
# ✅ New best saved: ./eval_results_minimal/single_scale_best.pth (loss=0.103394)
# Epoch 27/50 | loss=0.100905
# ✅ New best saved: ./eval_results_minimal/single_scale_best.pth (loss=0.100905)
# Epoch 28/50 | loss=0.102528
# Epoch 29/50 | loss=0.105388
# Epoch 30/50 | loss=0.094310
# ✅ New best saved: ./eval_results_minimal/single_scale_best.pth (loss=0.094310)
# Epoch 31/50 | loss=0.088846
# ✅ New best saved: ./eval_results_minimal/single_scale_best.pth (loss=0.088846)
# Epoch 32/50 | loss=0.082457
# ✅ New best saved: ./eval_results_minimal/single_scale_best.pth (loss=0.082457)
# Epoch 33/50 | loss=0.078891
# ✅ New best saved: ./eval_results_minimal/single_scale_best.pth (loss=0.078891)
# Epoch 34/50 | loss=0.071492
# ✅ New best saved: ./eval_results_minimal/single_scale_best.pth (loss=0.071492)
# Epoch 35/50 | loss=0.065458
# ✅ New best saved: ./eval_results_minimal/single_scale_best.pth (loss=0.065458)
# Epoch 36/50 | loss=0.067602
# Epoch 37/50 | loss=0.055326
# ✅ New best saved: ./eval_results_minimal/single_scale_best.pth (loss=0.055326)
# Epoch 38/50 | loss=0.055966
# Epoch 39/50 | loss=0.044431
# ✅ New best saved: ./eval_results_minimal/single_scale_best.pth (loss=0.044431)
# Epoch 40/50 | loss=0.048133
# Epoch 41/50 | loss=0.044932
# Epoch 42/50 | loss=0.041948
# ✅ New best saved: ./eval_results_minimal/single_scale_best.pth (loss=0.041948)
# Epoch 43/50 | loss=0.040710
# ✅ New best saved: ./eval_results_minimal/single_scale_best.pth (loss=0.040710)
# Epoch 44/50 | loss=0.045504
# Epoch 45/50 | loss=0.044887
# Epoch 46/50 | loss=0.033419
# ✅ New best saved: ./eval_results_minimal/single_scale_best.pth (loss=0.033419)
# Epoch 47/50 | loss=0.032724
# ✅ New best saved: ./eval_results_minimal/single_scale_best.pth (loss=0.032724)
# Epoch 48/50 | loss=0.039550
# Epoch 49/50 | loss=0.032685
# ✅ New best saved: ./eval_results_minimal/single_scale_best.pth (loss=0.032685)
# Epoch 50/50 | loss=0.026782
# ✅ New best saved: ./eval_results_minimal/single_scale_best.pth (loss=0.026782)
# Eval | MSE=0.037897 | R2=0.9999
# Saved plot: ./eval_results_minimal/single_scale_traj.png
# [multi_scale] alpha_scales=[0.0, 0.5, 1.0] -> strides=(1, 2, 4)
# /tmp/ipykernel_2210756/3220069749.py:71: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   yaw = np.asarray(data.get("yaw", []), dtype=np.float32)
# Epoch 1/50 | loss=8.057959
# ✅ New best saved: ./eval_results_minimal/multi_scale_best.pth (loss=8.057959)
# Epoch 2/50 | loss=2.472524
# ✅ New best saved: ./eval_results_minimal/multi_scale_best.pth (loss=2.472524)
# Epoch 3/50 | loss=1.178203
# ✅ New best saved: ./eval_results_minimal/multi_scale_best.pth (loss=1.178203)
# Epoch 4/50 | loss=0.748513
# ✅ New best saved: ./eval_results_minimal/multi_scale_best.pth (loss=0.748513)
# Epoch 5/50 | loss=0.555685
# ✅ New best saved: ./eval_results_minimal/multi_scale_best.pth (loss=0.555685)
# Epoch 6/50 | loss=0.410240
# ✅ New best saved: ./eval_results_minimal/multi_scale_best.pth (loss=0.410240)
# Epoch 7/50 | loss=0.360838
# ✅ New best saved: ./eval_results_minimal/multi_scale_best.pth (loss=0.360838)
# Epoch 8/50 | loss=0.307935
# ✅ New best saved: ./eval_results_minimal/multi_scale_best.pth (loss=0.307935)
# Epoch 9/50 | loss=0.291277
# ✅ New best saved: ./eval_results_minimal/multi_scale_best.pth (loss=0.291277)
# Epoch 10/50 | loss=0.270635
# ✅ New best saved: ./eval_results_minimal/multi_scale_best.pth (loss=0.270635)
# Epoch 11/50 | loss=0.244419
# ✅ New best saved: ./eval_results_minimal/multi_scale_best.pth (loss=0.244419)
# Epoch 12/50 | loss=0.206653
# ✅ New best saved: ./eval_results_minimal/multi_scale_best.pth (loss=0.206653)
# Epoch 13/50 | loss=0.191236
# ✅ New best saved: ./eval_results_minimal/multi_scale_best.pth (loss=0.191236)
# Epoch 14/50 | loss=0.175633
# ✅ New best saved: ./eval_results_minimal/multi_scale_best.pth (loss=0.175633)
# Epoch 15/50 | loss=0.183873
# Epoch 16/50 | loss=0.154589
# ✅ New best saved: ./eval_results_minimal/multi_scale_best.pth (loss=0.154589)
# Epoch 17/50 | loss=0.147037
# ✅ New best saved: ./eval_results_minimal/multi_scale_best.pth (loss=0.147037)
# Epoch 18/50 | loss=0.165898
# Epoch 19/50 | loss=0.131576
# ✅ New best saved: ./eval_results_minimal/multi_scale_best.pth (loss=0.131576)
# Epoch 20/50 | loss=0.129606
# ✅ New best saved: ./eval_results_minimal/multi_scale_best.pth (loss=0.129606)
# Epoch 21/50 | loss=0.119593
# ✅ New best saved: ./eval_results_minimal/multi_scale_best.pth (loss=0.119593)
# Epoch 22/50 | loss=0.112881
# ✅ New best saved: ./eval_results_minimal/multi_scale_best.pth (loss=0.112881)
# Epoch 23/50 | loss=0.107052
# ✅ New best saved: ./eval_results_minimal/multi_scale_best.pth (loss=0.107052)
# Epoch 24/50 | loss=0.110588
# Epoch 25/50 | loss=0.093838
# ✅ New best saved: ./eval_results_minimal/multi_scale_best.pth (loss=0.093838)
# Epoch 26/50 | loss=0.094107
# Epoch 27/50 | loss=0.109234
# Epoch 28/50 | loss=0.083615
# ✅ New best saved: ./eval_results_minimal/multi_scale_best.pth (loss=0.083615)
# Epoch 29/50 | loss=0.072192
# ✅ New best saved: ./eval_results_minimal/multi_scale_best.pth (loss=0.072192)
# Epoch 30/50 | loss=0.076994
# Epoch 31/50 | loss=0.065537
# ✅ New best saved: ./eval_results_minimal/multi_scale_best.pth (loss=0.065537)
# Epoch 32/50 | loss=0.062771
# ✅ New best saved: ./eval_results_minimal/multi_scale_best.pth (loss=0.062771)
# Epoch 33/50 | loss=0.061543
# ✅ New best saved: ./eval_results_minimal/multi_scale_best.pth (loss=0.061543)
# Epoch 34/50 | loss=0.072566
# Epoch 35/50 | loss=0.066463
# Epoch 36/50 | loss=0.063257
# Epoch 37/50 | loss=0.064860
# Epoch 38/50 | loss=0.055649
# ✅ New best saved: ./eval_results_minimal/multi_scale_best.pth (loss=0.055649)
# Epoch 39/50 | loss=0.056587
# Epoch 40/50 | loss=0.058474
# Epoch 41/50 | loss=0.056831
# Epoch 42/50 | loss=0.053087
# ✅ New best saved: ./eval_results_minimal/multi_scale_best.pth (loss=0.053087)
# Epoch 43/50 | loss=0.055468
# Epoch 44/50 | loss=0.042097
# ✅ New best saved: ./eval_results_minimal/multi_scale_best.pth (loss=0.042097)
# Epoch 45/50 | loss=0.046518
# Epoch 46/50 | loss=0.052448
# Epoch 47/50 | loss=0.046962
# Epoch 48/50 | loss=0.046953
# Epoch 49/50 | loss=0.042619
# Epoch 50/50 | loss=0.041661
# ✅ New best saved: ./eval_results_minimal/multi_scale_best.pth (loss=0.041661)
# Eval | MSE=0.125369 | R2=0.9997
# Saved plot: ./eval_results_minimal/multi_scale_traj.png
# ✅ Step 2 summary saved: ./eval_results_minimal/ablation_step2_single_vs_multi.csv
#         MSE        R2           exp     alpha_scales    strides
# 0  0.037897  0.999906  single_scale            [0.0]       (1,)
# 1  0.125369  0.999679   multi_scale  [0.0, 0.5, 1.0]  (1, 2, 4)

# %% [markdown]
# # Step 3: Core ablation #2 — No-fast / No-med / No-slow (standard output)
# We reuse your `evalcell.evaluate_time_scales_and_extensions`.
#
# Important: in your paper, temporal scale **α ∈ [0,1]**.
# Here we map α thresholds to integer time-step thresholds using the current batch max length **T**:
# - `fast_thr = round(α_fast * T)`
# - `slow_thr = round(α_slow * T)`
#
# Spatial scale **λ ∈ [0,1]** is handled in your separate scale-factor experiments (e.g., `ablation_scales.py`).

# %%
# === 8) Step 3: No-fast / No-med / No-slow using alpha thresholds in [0,1] ===

MODEL_CKPT = os.path.join(SAVE_DIR, "multi_scale_best.pth")
assert os.path.exists(MODEL_CKPT), f"Missing checkpoint: {MODEL_CKPT}"

# Rebuild the same multi-scale model architecture for analysis
strides = make_strides_from_alpha([0.0, 0.5, 1.0])
ms_model = MultiScaleVisualTemporalNet(
    feature_dim=dataset.input_feature_dim,
    hidden_dim=HIDDEN_DIM,
    visual_dim=VISUAL_DIM,
    output_dim=dataset.target_dim,
    strides=strides
).to(device)

ms_model.load_state_dict(torch.load(MODEL_CKPT, map_location=device))
ms_model.eval()

# 1) 必须先得到 results（hidden_concat / cell_timescale）
#    注意：plotcell 的签名是 n_cells_to_plot，不是 max_cells_to_analyze
results = plotcell.analyze_time_cells(
    model=ms_model,
    loader=loader,
    device=device,
    n_cells_to_plot=64,
    save_dir=SAVE_DIR
)

# 2) alpha -> threshold
probe = next(iter(loader))
feats_p, imgs_p, targets_p, mask_p = probe
T_max = feats_p.shape[1]

alpha_fast = 0.2
alpha_slow = 0.6
fast_thr = max(1, int(round(alpha_fast * T_max)))
slow_thr = max(fast_thr + 1, int(round(alpha_slow * T_max)))

print(f"T_max={T_max}, alpha_fast={alpha_fast} -> fast_thr={fast_thr}, alpha_slow={alpha_slow} -> slow_thr={slow_thr}")

# 3) 调用 evalcell（按你 evalcell.py 的签名传参）
evalcell.evaluate_time_scales_and_extensions(
    model=ms_model,
    loader=loader,
    results=results,
    device=device,
    thresholds=(fast_thr, slow_thr),
    save_dir=SAVE_DIR
)

print("✅ Step 3 outputs (bar/csv/cross-traj) saved under:", SAVE_DIR)
# Out:
# /tmp/ipykernel_2210756/3220069749.py:71: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   yaw = np.asarray(data.get("yaw", []), dtype=np.float32)
# Hidden states padded to (2892, 849, 128)
# /tmp/ipykernel_2210756/3220069749.py:71: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   yaw = np.asarray(data.get("yaw", []), dtype=np.float32)
# T_max=130, alpha_fast=0.2 -> fast_thr=26, alpha_slow=0.6 -> slow_thr=78
# Running ablation analysis...
# Ablation evaluation completed.
# ✅ Step 3 outputs (bar/csv/cross-traj) saved under: ./eval_results_minimal

# %%
# === 9) Cognitive relation analysis (pos/yaw/velocity correlations) ===
evaltraj.evaluate_timecell_trajectory_correlation(
    model=ms_model,
    loader=loader,
    results=results,
    device=device,
    save_dir=SAVE_DIR
)
print("✅ Relation analysis saved under:", SAVE_DIR)
# Out:
# /tmp/ipykernel_2210756/3220069749.py:71: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   yaw = np.asarray(data.get("yaw", []), dtype=np.float32)
# Data prepared: Hidden=(2892, 849, 128), Pos=(2892, 849, 2)
# Calculating correlations...
# Correlation analysis completed.
# ✅ Relation analysis saved under: ./eval_results_minimal
